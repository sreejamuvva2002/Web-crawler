# %% [markdown]
# # Review domain coverage
# Which domains dominate discovery, and how are they prioritized?

# %%
import pandas as pd

summary = pd.read_csv('../data/urls/domain_summary.csv')
summary.head(30)

# %%
summary.groupby('priority')['url_count'].sum()

# %%
frontier = pd.read_csv('../data/urls/url_frontier.csv')
frontier.groupby(['priority', 'status']).size().unstack(fill_value=0)
