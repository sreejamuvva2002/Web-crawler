# %% [markdown]
# # Review URL candidates
# Inspect raw/deduped URL candidates from Stage 1.

# %%
import pandas as pd

raw = pd.read_csv('../data/urls/url_candidates_raw.csv')
print(len(raw), 'raw candidates')
raw.head(20)

# %%
deduped = pd.read_csv('../data/urls/url_candidates_deduped.csv')
print(len(deduped), 'unique candidates')
deduped['search_engine'].value_counts()

# %%
deduped['query_used'].value_counts().head(20)
